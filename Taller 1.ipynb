# %%
identificacion = input ("Digite su numero de Identificacion: ")
nombres = input ("Escriba su nombre: ")
apellidos = input ("Escriba su apellido: ")
direccion = input ("Escriba su dirección: ")
telefono = input ("Digite su telefono celular: ")
edad = input ("¿Cual es su edad?: ")
estadoCivil = input ("Estado Civil: ")
numeroHijos = input ("¿Cuantos hijos tienes? ")
estaturaCen = input ("Digite su estatura en centimetros: ")
fechaContra = input ("¿Cual es su fecha de Contratacion? (Dia/mes/año): ")
sueldoBasico = input ("Digite su sueldo: ")
diasLaborados = input ("Dias Laborados: ")

print (identificacion)
print (nombres)
print (apellidos)
print (direccion)
print (telefono)
print (edad)
print (estadoCivil)
print (numeroHijos)
print (estaturaCen)
print (fechaContra)
print (sueldoBasico)
print (diasLaborados)
# Out:
# Digite su numero de Identificacion: 1234567
# Escriba su nombre: Yamid
# Escriba su apellido: Ruiz
# Escriba su dirección: Carrera 103B No 82 - 48
# Digite su telefono celular: 3157807665
# ¿Cual es su edad?: 40
# Estado Civil: Union Libre
# ¿Cuantos hijos tienes? 3
# Digite su estatura en centimetros: 171
# ¿Cual es su fecha de Contratacion? (Dia/mes/año): 12/03/2018
# Digite su sueldo: 20000000
# Dias Laborados: 30
# 1234567
# Yamid
# Ruiz
# Carrera 103B No 82 - 48
# 3157807665
# 40
# Union Libre
# 3
# 171
# 12/03/2018
# 20000000
# 30
